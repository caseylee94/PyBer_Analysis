# %% [markdown]
# # Pyber Challenge

# %% [markdown]
# ### 4.3 Loading and Reading CSV files

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# File to Load (Remember to change these)
city_data_to_load = "Resources/city_data.csv"
ride_data_to_load = "Resources/ride_data.csv"

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %% [markdown]
# ### Merge the DataFrames

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the data table for preview
pyber_data_df.head(10)
# pyber_data_df.describe()
# Out:
#                  city             date   fare       ride_id  driver_count  \
# 0  Lake Jonathanshire  1/14/2019 10:14  13.83  5.739410e+12             5
# 1  South Michelleport   3/4/2019 18:24  30.24  2.343910e+12            72
# 2  Port Samanthamouth   2/24/2019 4:29  33.44  2.005070e+12            57
# 3          Rodneyfort  2/10/2019 23:22  23.44  5.149250e+12            34
# 4          South Jack    3/6/2019 4:28  34.58  3.908450e+12            46
# 5        South Latoya  3/11/2019 12:26   9.52  1.995000e+12            10
# 6       New Paulville  2/27/2019 11:17  43.25  7.932080e+11            44
# 7        Simpsonburgh   4/26/2019 0:43  35.98  1.119540e+11            21
# 8     South Karenland    1/8/2019 3:28  35.09  7.995620e+12             4
# 9       North Jasmine    3/9/2019 6:26  42.81  5.327640e+12            33
#
#     type
# 0  Urban
# 1  Urban
# 2  Urban
# 3  Urban
# 4  Urban
# 5  Urban
# 6  Urban
# 7  Urban
# 8  Urban
# 9  Urban

# %% [markdown]
# ## Deliverable 1: Get a Summary DataFrame

# %%
#  1. Get the total rides for each city type

total_rides = pyber_data_df.groupby(["type"]).count()["ride_id"]
total_rides
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: ride_id, dtype: int64

# %%
# 2. Get the total drivers for each city type

total_drivers = city_data_df.groupby(["type"]).sum()["driver_count"]
total_drivers
# Out:
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %%
#  3. Get the total amount of fares for each city type

total_fares = pyber_data_df.groupby(["type"]).sum()["fare"]
total_fares
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
#  4. Get the average fare per ride for each city type. 

average_fare = total_fares / total_rides
average_fare
# Out:
# type
# Rural       34.623440
# Suburban    30.970128
# Urban       24.525772
# dtype: float64

# %%
# 5. Get the average fare per driver for each city type. 

avg_fare_per_driver = total_fares / total_drivers
avg_fare_per_driver
# Out:
# type
# Rural       55.486282
# Suburban    39.502714
# Urban       16.571468
# dtype: float64

# %%
#  6. Create a PyBer summary DataFrame. 

pyber_summary_df = pd.DataFrame(
    {"Total Rides": total_rides,
      "Total Drivers": total_drivers,
      "Total Fares": total_fares,
      "Average Fare per Ride": average_fare,
      "Average Fare per Driver": avg_fare_per_driver})
pyber_summary_df


# per_school_types = school_data_df.set_index(["school_name"])["type"]
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# type
# Rural             125             78      4327.93              34.623440
# Suburban          625            490     19356.33              30.970128
# Urban            1625           2405     39854.38              24.525772
#
#           Average Fare per Driver
# type
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
#  7. Cleaning up the DataFrame. Delete the index name
pyber_summary_df.index.name = None

# %%
#  8. Format the columns.

pyber_summary_df['Total Rides'] = pyber_summary_df['Total Rides'].map("{:,.0f}".format)
pyber_summary_df['Total Drivers'] = pyber_summary_df['Total Drivers'].map("{:,.0f}".format)
pyber_summary_df['Total Fares'] = pyber_summary_df['Total Fares'].map("${:,.2f}".format)
pyber_summary_df['Average Fare per Ride'] = pyber_summary_df['Average Fare per Ride'].map("${:,.2f}".format)
pyber_summary_df['Average Fare per Driver'] = pyber_summary_df['Average Fare per Driver'].map("${:,.2f}".format)
pyber_summary_df
# Out:
#          Total Rides Total Drivers Total Fares Average Fare per Ride  \
# Rural            125            78   $4,327.93                $34.62
# Suburban         625           490  $19,356.33                $30.97
# Urban          1,625         2,405  $39,854.38                $24.53
#
#          Average Fare per Driver
# Rural                     $55.49
# Suburban                  $39.50
# Urban                     $16.57

# %% [markdown]
# ## Deliverable 2.  Create a multiple line plot that shows the total weekly of the fares for each type of city.

# %%
# 1. Read the merged DataFrame
pyber_data_df.head(10)
# Out:
#                  city             date   fare       ride_id  driver_count  \
# 0  Lake Jonathanshire  1/14/2019 10:14  13.83  5.739410e+12             5
# 1  South Michelleport   3/4/2019 18:24  30.24  2.343910e+12            72
# 2  Port Samanthamouth   2/24/2019 4:29  33.44  2.005070e+12            57
# 3          Rodneyfort  2/10/2019 23:22  23.44  5.149250e+12            34
# 4          South Jack    3/6/2019 4:28  34.58  3.908450e+12            46
# 5        South Latoya  3/11/2019 12:26   9.52  1.995000e+12            10
# 6       New Paulville  2/27/2019 11:17  43.25  7.932080e+11            44
# 7        Simpsonburgh   4/26/2019 0:43  35.98  1.119540e+11            21
# 8     South Karenland    1/8/2019 3:28  35.09  7.995620e+12             4
# 9       North Jasmine    3/9/2019 6:26  42.81  5.327640e+12            33
#
#     type
# 0  Urban
# 1  Urban
# 2  Urban
# 3  Urban
# 4  Urban
# 5  Urban
# 6  Urban
# 7  Urban
# 8  Urban
# 9  Urban

# %%
# 2. Using groupby() to create a new DataFrame showing the sum of the fares 
#  for each date where the indices are the city type and date.

sum_fares_by_date=pyber_data_df.groupby(["type", "date"]).sum()[["fare"]]
# sum_fares_by_date=pyber_data_df.loc[pyber_data_df["type"]=="Rural"]
sum_fares_by_date.head(10)
# sum_fares_by_date.sort_values(by="date").head(10)
# Out:
#                         fare
# type  date
# Rural 1/1/2019 9:45    43.69
#       1/11/2019 4:39   16.42
#       1/14/2019 15:58  54.10
#       1/14/2019 7:09   18.05
#       1/15/2019 21:44  30.26
#       1/18/2019 0:46   15.12
#       1/18/2019 7:36   43.57
#       1/19/2019 11:40  49.44
#       1/19/2019 12:38  38.68
#       1/19/2019 20:21  56.78

# %%
# 3. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.
# df = df.reset_index()

sum_fares_by_date = sum_fares_by_date.reset_index()
sum_fares_by_date.head(10)
# Out:
#     type             date   fare
# 0  Rural    1/1/2019 9:45  43.69
# 1  Rural   1/11/2019 4:39  16.42
# 2  Rural  1/14/2019 15:58  54.10
# 3  Rural   1/14/2019 7:09  18.05
# 4  Rural  1/15/2019 21:44  30.26
# 5  Rural   1/18/2019 0:46  15.12
# 6  Rural   1/18/2019 7:36  43.57
# 7  Rural  1/19/2019 11:40  49.44
# 8  Rural  1/19/2019 12:38  38.68
# 9  Rural  1/19/2019 20:21  56.78

# %%
# 4. Create a pivot table with the 'date' as the index, the columns ='type', and values='fare' 
# to get the total fares for each type of city by the date. 

sum_fares_by_date_pivot = sum_fares_by_date.pivot(index="date", columns="type", values="fare")
sum_fares_by_date_pivot.head(20)
# Out:
# type             Rural  Suburban  Urban
# date
# 1/1/2019 0:08      NaN       NaN  37.91
# 1/1/2019 0:46      NaN     47.74    NaN
# 1/1/2019 12:32     NaN     25.56    NaN
# 1/1/2019 14:40     NaN       NaN   5.42
# 1/1/2019 14:42     NaN       NaN  12.31
# 1/1/2019 14:52     NaN     31.15    NaN
# 1/1/2019 17:22     NaN       NaN  42.11
# 1/1/2019 21:04     NaN       NaN  11.71
# 1/1/2019 2:07      NaN     24.07    NaN
# 1/1/2019 3:46      NaN       NaN   7.57
# 1/1/2019 5:23      NaN       NaN  10.75
# 1/1/2019 9:45    43.69       NaN    NaN
# 1/10/2019 0:17     NaN     47.52    NaN
# 1/10/2019 11:08    NaN     37.96    NaN
# 1/10/2019 11:10    NaN     40.20    NaN
# 1/10/2019 11:15    NaN     24.65    NaN
# 1/10/2019 12:17    NaN       NaN  12.74
# 1/10/2019 12:41    NaN     49.19    NaN
# 1/10/2019 17:29    NaN       NaN  19.91
# 1/10/2019 19:17    NaN     33.85    NaN

# %%
# 5. Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-29'.

filtered_fares_df = sum_fares_by_date_pivot.loc['1/1/2019':'4/28/2019']
filtered_fares_df.head(20)
# Out:
# type             Rural  Suburban  Urban
# date
# 1/1/2019 0:08      NaN       NaN  37.91
# 1/1/2019 0:46      NaN     47.74    NaN
# 1/1/2019 12:32     NaN     25.56    NaN
# 1/1/2019 14:40     NaN       NaN   5.42
# 1/1/2019 14:42     NaN       NaN  12.31
# 1/1/2019 14:52     NaN     31.15    NaN
# 1/1/2019 17:22     NaN       NaN  42.11
# 1/1/2019 21:04     NaN       NaN  11.71
# 1/1/2019 2:07      NaN     24.07    NaN
# 1/1/2019 3:46      NaN       NaN   7.57
# 1/1/2019 5:23      NaN       NaN  10.75
# 1/1/2019 9:45    43.69       NaN    NaN
# 1/10/2019 0:17     NaN     47.52    NaN
# 1/10/2019 11:08    NaN     37.96    NaN
# 1/10/2019 11:10    NaN     40.20    NaN
# 1/10/2019 11:15    NaN     24.65    NaN
# 1/10/2019 12:17    NaN       NaN  12.74
# 1/10/2019 12:41    NaN     49.19    NaN
# 1/10/2019 17:29    NaN       NaN  19.91
# 1/10/2019 19:17    NaN     33.85    NaN

# %%
# 6. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.
# df.index = pd.to_datetime(df.index)
type(filtered_fares_df.index)
filtered_fares_df.index = pd.to_datetime(filtered_fares_df.index)
filtered_fares_df.tail(10)
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-04-27 20:41:00    NaN       NaN   8.28
# 2019-04-27 23:26:00    NaN       NaN  19.06
# 2019-04-27 23:52:00    NaN     45.98    NaN
# 2019-04-27 02:28:00    NaN     14.01    NaN
# 2019-04-27 05:31:00    NaN     36.11    NaN
# 2019-04-27 06:02:00  38.33       NaN    NaN
# 2019-04-27 06:20:00    NaN     28.29    NaN
# 2019-04-27 07:18:00    NaN     18.56    NaN
# 2019-04-27 07:34:00    NaN     30.28    NaN
# 2019-04-27 08:48:00    NaN       NaN  12.84

# %%
# 7. Check that the datatype for the index is datetime using df.info()

filtered_fares_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2038 entries, 2019-01-01 00:08:00 to 2019-04-27 08:48:00
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rural     105 non-null    float64
#  1   Suburban  532 non-null    float64
#  2   Urban     1403 non-null   float64
# dtypes: float64(3)
# memory usage: 63.7 KB

# %%
# 8. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.

fares_per_week_df = filtered_fares_df.resample("W").sum()
fares_per_week_df.head(10)
# Out:
# type         Rural  Suburban    Urban
# date
# 2019-01-06  187.92    721.60  1661.68
# 2019-01-13   67.65   1105.13  2050.43
# 2019-01-20  306.00   1218.20  1939.02
# 2019-01-27  179.69   1203.28  2129.51
# 2019-02-03  333.08   1042.79  2086.94
# 2019-02-10  115.80    974.34  2162.64
# 2019-02-17   95.82   1045.50  2235.07
# 2019-02-24  419.06   1412.74  2466.29
# 2019-03-03  175.14    858.46  2218.20
# 2019-03-10  303.94    925.27  2470.93

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function. 

# Import the style from Matplotlib.
from matplotlib import style
fares_per_week_df.plot(figsize=(15, 5))

# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')

# Add title and axis titles
plt.title("Total Fare by City Type")
plt.xlabel("Month")
plt.ylabel("Fares ($USD)")

# Save figure NOTE: In resources folder with other plots, not analysis
plt.savefig("Resources/Fig8.png")

# Show graph
plt.show()

# NOTE: My line graph is showing a difference in the data output just for the month of April compared to the graph shown 
# in the instructions for the challenge. I met with a tutor and tried to debug the code but it does not seem to be the 
# code itself, maybe there is a discrepancy in the data for April due to an update or some other change?
